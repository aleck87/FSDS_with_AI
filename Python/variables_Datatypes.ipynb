# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:11:29) [Clang 20.1.8 ]'

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
name = 'Deepak'
fullname = ''' John
Living in America
with his father '''
print (name)
print (fullname)
# Out:
# Deepak
#  John
# Living in America
# with his father

# %%
type(name)
type(fullname)
# Out:
# str

# %%
type(fullname)
# Out:
# str

# %%
mine= 'Deepak'
mine
# Out:
# 'Deepak'

# %%
id(name)
id(mine)
# Out:
# 4414219216

# %%
id(name)
id(mine)
id(fullname)
# Out:
# 4413831376

# %%
id(name)
# Out:
# 4414219216

# %%
id(mine)
# Out:
# 4414219216

# %%
id(fullname)
# Out:
# 4413831376

# %%
fullname
# Out:
# ' John\nLiving in America\nwith his father '

# %%
age, place, married = 38, 'Indore', 'No'
print (name,'is', age, 'old and lives in', place, '. Is he married ? - ', married)
# Out:
# Deepak is 38 old and lives in Indore . Is he married ? -  No

# %%
add_str = name + fullname

# %%
add_str
# Out:
# 'Deepak John\nLiving in America\nwith his father '

# %%
print(add_str)
# Out:
# Deepak John
# Living in America
# with his father

# %% [markdown]
# #### Working with Opraters

# %%
i, f, b, com = 5, 3.0, True, 3+7j

# %%
print (i, f, b, com)
# Out:
# 5 3.0 True (3+7j)

# %%
i/f
# Out:
# 1.6666666666666667

# %%
10/2
# Out:
# 5.0

# %% [markdown]
# Division end up in float value but with // result is integer

# %%
10//2
# Out:
# 5

# %%
3**2 #square is **
# Out:
# 9

# %%
3**3 # and so the qube with power 3 **
# Out:
# 27

# %%
10%5

print (9%2) # modules
# Out:
# 1

# %%
10%5
# Out:
# 0

# %% [markdown]
# ### Bodmas
# Brackets (solve everything inside brackets first)
# Orders (evaluate powers, indices, or roots)
# Division and Multiplication (these are evaluated from left to right)
# Addition and Subtraction (these are evaluated from left to right )

# %%
12/3*6+2e3-(2e2)
# Out:
# 1824.0

# %% [markdown]
# e = exponential means 10

# %%
10e2
# Out:
# 1000.0

# %%
-10E2 # capital E is also same as e
# Out:
# -1000.0

# %%
com = 10 + 30j
print(com)
# Out:
# (10+30j)

# %%
com.real
# Out:
# 10.0

# %%
com.imag
# Out:
# 30.0

# %%
com.conjugate
# Out:
# <function complex.conjugate()>

# %%
com.conjugate()
# Out:
# (10-30j)
